# %%
#| hide
from alma_tv import *

# %% [markdown]
# # alma-tv
#
# > Raspberry Pi automation suite for scheduling and playing curated children's programming

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install alma-tv in Development mode

# %% [markdown]
# ```sh
# # make sure alma-tv package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to alma_tv
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/danieljelinko/alma-tv.git
# ```
#
# [repo]: https://github.com/danieljelinko/alma-tv
# [docs]: https://danieljelinko.github.io/alma-tv/

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs].
#
# [repo]: https://github.com/danieljelinko/alma-tv
# [docs]: https://danieljelinko.github.io/alma-tv/

# %% [markdown]
# ## How to use

# %% [markdown]
# ### Quick Start
#
# Alma TV is designed to run on a Raspberry Pi and provides automated scheduling and playback of curated children's programming.
